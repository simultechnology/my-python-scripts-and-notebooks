# %%
print("start!")
# Out:
# start!

# %%
import pandas as pd

# %%
import sys
print(sys.path)
# Out:
# ['/Users/t_ishikawa/workspace/python_work/my-python-scripts-and-notebooks', '/usr/local/var/pyenv/versions/3.7.3/lib/python37.zip', '/usr/local/var/pyenv/versions/3.7.3/lib/python3.7', '/usr/local/var/pyenv/versions/3.7.3/lib/python3.7/lib-dynload', '', '/Users/t_ishikawa/workspace/python_work/my-python-scripts-and-notebooks/venv/lib/python3.7/site-packages', '/Users/t_ishikawa/workspace/python_work/my-python-scripts-and-notebooks/venv/lib/python3.7/site-packages/IPython/extensions', '/Users/t_ishikawa/.ipython']

# %%
first_rows = pd.read_csv('data/pokemon.csv')

# %%
first_rows.iloc[:9]
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3     ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4     ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 5     ['Blaze', 'Solar Power']         0.25           1.0             1.0
# 6     ['Torrent', 'Rain Dish']         1.00           1.0             1.0
# 7     ['Torrent', 'Rain Dish']         1.00           1.0             1.0
# 8     ['Torrent', 'Rain Dish']         1.00           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# ...
