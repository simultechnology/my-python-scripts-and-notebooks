# %%
print("start!")
# Out:
# start!

# %%
import pandas as pd

# %%
import sys
print(sys.path)
# Out:
# ['/Users/t_ishikawa/workspace/python_work/my-python-scripts-and-notebooks', '/usr/local/var/pyenv/versions/3.7.3/lib/python37.zip', '/usr/local/var/pyenv/versions/3.7.3/lib/python3.7', '/usr/local/var/pyenv/versions/3.7.3/lib/python3.7/lib-dynload', '', '/Users/t_ishikawa/workspace/python_work/my-python-scripts-and-notebooks/venv/lib/python3.7/site-packages', '/Users/t_ishikawa/workspace/python_work/my-python-scripts-and-notebooks/venv/lib/python3.7/site-packages/IPython/extensions', '/Users/t_ishikawa/.ipython']

# %%
df = pd.read_csv('data/pokemon.csv')

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
first_rows = df.iloc[:10, 1:5]

# %%
print(first_rows)
# Out:
#    against_bug  against_dark  against_dragon  against_electric
# 0         1.00           1.0             1.0               0.5
# 1         1.00           1.0             1.0               0.5
# 2         1.00           1.0             1.0               0.5
# 3         0.50           1.0             1.0               1.0
# 4         0.50           1.0             1.0               1.0
# 5         0.25           1.0             1.0               2.0
# 6         1.00           1.0             1.0               2.0
# 7         1.00           1.0             1.0               2.0
# 8         1.00           1.0             1.0               2.0
# 9         1.00           1.0             1.0               1.0

# %%
first_rows
# Out:
#    against_bug  against_dark  against_dragon  against_electric
# 0         1.00           1.0             1.0               0.5
# 1         1.00           1.0             1.0               0.5
# 2         1.00           1.0             1.0               0.5
# 3         0.50           1.0             1.0               1.0
# 4         0.50           1.0             1.0               1.0
# 5         0.25           1.0             1.0               2.0
# 6         1.00           1.0             1.0               2.0
# 7         1.00           1.0             1.0               2.0
# 8         1.00           1.0             1.0               2.0
# 9         1.00           1.0             1.0               1.0

# %%
first_rows.describe()
# Out:
#        against_bug  against_dark  against_dragon  against_electric
# count    10.000000          10.0            10.0         10.000000
# mean      0.825000           1.0             1.0          1.250000
# std       0.289875           0.0             0.0          0.677003
# min       0.250000           1.0             1.0          0.500000
# 25%       0.625000           1.0             1.0          0.625000
# 50%       1.000000           1.0             1.0          1.000000
# 75%       1.000000           1.0             1.0          2.000000
# max       1.000000           1.0             1.0          2.000000

# %%
import matplotlib.pyplot as plt

# %%
df.plot()

# %%
type(first_rows.describe())
# Out:
# pandas.core.frame.DataFrame

# %%
ds = first_rows.describe()

# %%
type(ds)
# Out:
# pandas.core.frame.DataFrame

# %%
ds.loc['count']
# Out:
# against_bug         10.0
# against_dark        10.0
# against_dragon      10.0
# against_electric    10.0
# Name: count, dtype: float64

# %%
mlt.plot(ds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-c5fa69e788a8> in <module>
# ----> 1 mlt.plot(ds)
#
# NameError: name 'mlt' is not defined

# %%
first_rows.plot()

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...
